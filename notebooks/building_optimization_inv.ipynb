# %%
import sys
sys.path.append("/home/docker/data/Optimization/")

# %%
from building_opt import building_opt_inv as bui

# %%
sim_res = bui.run_simulation()
# Out:
# ---------------------------------------------------------------------------
# CompilerError                             Traceback (most recent call last)
# <ipython-input-3-9933dc55d299> in <module>()
# ----> 1 sim_res = bui.run_simulation()
#
# /home/docker/data/Optimization/building_opt/building_opt_inv.pyc in run_simulation()
#     100     # Compile FMU
#     101     path = os.path.join(curr_dir,"..","Models","ElectricalNetwork.mop")
# --> 102     fmu_model = compile_fmu('ElectricNetwork.RCBuildingModel2_Inv', path)
#     103
#     104     # Load the model instance into Python
#
# /home/docker/installed/JModelica/Python/pymodelica/compiler.pyc in compile_fmu(class_name, file_name, compiler, target, version, platform, compiler_options, compile_to, compiler_log_level, separate_process, jvm_args)
#     148     return _compile_unit(class_name, file_name, compiler, target, version,
#     149                 platform, compiler_options, compile_to, compiler_log_level,
# --> 150                 separate_process, jvm_args)
#     151
#     152 def compile_fmux(class_name, file_name=[], compiler='auto', compiler_options={},
#
# /home/docker/installed/JModelica/Python/pymodelica/compiler.pyc in _compile_unit(class_name, file_name, compiler, target, version, platform, compiler_options, compile_to, compiler_log_level, separate_process, jvm_args)
#     352     else:
#     353         return compile_separate_process(class_name, file_name, compiler, target, version, platform,
# --> 354                                         compiler_options, compile_to, compiler_log_level, jvm_args)
#     355
#     356 def compile_separate_process(class_name, file_name=[], compiler='auto', target='me', version='1.0',
#
# /home/docker/installed/JModelica/Python/pymodelica/compiler.pyc in compile_separate_process(class_name, file_name, compiler, target, version, platform, compiler_options, compile_to, compiler_log_level, jvm_args)
#     471         process.wait();
#     472     finally:
# --> 473         return log.end();
#     474
#     475 def _gen_compiler_options(compiler_options):
#
# /home/docker/installed/JModelica/Python/pymodelica/compiler_logging.pyc in end(self)
#     304                 return CompilerResult(name, warnings)
#     305             else:
# --> 306                 raise CompilerError(errors, warnings)
#     307
#     308         exception = exceptions[0]
#
# CompilerError:
# 2 error(s) and 0 warning(s) found:
#
# Error: in file '/tmp/jmc8738084153301708838out/sources/ElectricNetwork.RCBuildingModel2_Inv.mof':
# Semantic error at line 0, column 0:
#   Index reduction failed: Maximum number of differentiations has been reached
#
# Error: in file '/tmp/jmc8738084153301708838out/sources/ElectricNetwork.RCBuildingModel2_Inv.mof':
# Semantic error at line 0, column 0:
#   The system is structurally singular. The following varible(s) could not be matched to any equation:
#      u_m_1
#
#   The following equation(s) could not be matched to any variable:
#     y_m[1] = Tmix

# %%
bui.plot_sim_res(sim_res)

# %%
plot(sim_res["P_hvac"])

# %%
opt_res_energy = bui.run_optimization(sim_res, "ElectricNetwork.BuildingMngmtOpt_E")

# %%
opt_res_money = bui.run_optimization(sim_res, "ElectricNetwork.BuildingMngmtOpt_Money")

# %%
bui.print_details(opt_res_money, opt_res_energy)

# %%
plot(opt_res_money["Money"] - opt_res_money["Money"][0], 'r')
plot(opt_res_energy["Money"] - opt_res_energy["Money"][0], 'b')

# %%
plot(opt_res_money["E"] - opt_res_money["E"][0], 'r')
plot(opt_res_energy["E"] - opt_res_energy["E"][0], 'b')

# %%
plot(opt_res_money["P_el"], 'r')
plot(opt_res_energy["P_el"], 'b')
